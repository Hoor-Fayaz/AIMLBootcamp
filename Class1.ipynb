# %%
#  machine learning workflow

# 1. Define the problem
# 2. Collect data
# 3. Clean & preprocess data
# 4. Train the model
# 5. Evaluate the model
# 6. Improve the model
# 7. Deploy the model

# %%
# # Types of Machine Learning

# Features -  height, weight, age, marks, 

# Labels  - pass/ fail

# # Supervised Learning 

# labeled data

# # Unsupervised Learning

# unlabeled data

# %%
print ("HIII")

# %%
a = 10
b = "Hello"
c = 8
print( a)
print( b)
print( a + c)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "/kaggle/input/irisiri/iris.csv"
)

df.head()

# %%
df.shape

# %%
df.info

# %%
df.describe()
