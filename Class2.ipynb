# %%
list = [10, "Helllo", True, 3.14]
print(list)

# %%
first = list[0]
print(first)

# %%
#slicing

slice = list[1:]
print(slice)

# %%
slice = list[-2]
print(slice)

# %%
#slicing

slice = list[0:2]
print(slice)

# %%
list.append(56)

print(list)

# %%
dict = {
    "name": "Ayesha",
    "age" : 23
    
}
print(dict)

# %%
age = dict["age"]
print(age)

# %%
dict["name"] = "xyz"

print(dict)

# %%
dict["marks"] = 453

print(dict)

# %%
score = 46


if score >= 80:
    print("pass")
elif score >= 50:
    print("xyz")
else:
    print("fail")

# %%
fruits = [ "apples", "banana", "orange"]
for i in fruits:
    print(f"I like {i}")

# %%
i = 1

while i<=7:
    print(i)
    i+=1

# %%
import pandas as pd

df = pd.read_csv(
    "/kaggle/input/iriiss/iris.csv"
)

df.head

# %%
print(df['sepal_length'].head())

# %%
print(df[['sepal_length','species']].head())

# %%
 setosa = df[df['species']== 'setosa']
print(setosa.head())

# %%
mean = df['sepal_width'].mean()
print(f"{mean:.2f}")

# %%
xyz = df.groupby('species')["sepal_width"].mean()

print(xyz)

# %%
def average(numbers):
    total = sum(numbers)
    avg = total/len(numbers)
    return avg

marks = [45,26,74]
answer = average(marks)

print(answer)
