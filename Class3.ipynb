# %%
# string manipulation



str = "Python is a good lang"


print(str[0])
print(str[-1])

# %%
print(str[3:9])
print(str[ :7])

# %%
upper = str.upper()
print(upper)
lower = str.lower()
print(lower)

# %%
words = str.split()
print(words)

joined_str = " ".join(words)
print(joined_str)

# %%
# list comprehension

numbers = [5,8,2,7]

squares = [ i ** 2 for i in numbers]

print(squares)

# %%
# NUMPY 


# fast numerical computation
# arrays matrices

# %%
import numpy as np

# %%
print( np.__version__)

# %%
arr = np.array([12,6,7,5])

print(arr)

# %%
print(arr.shape)
print(arr.ndim)
print(arr.dtype)

# %%
zero = np.zeros(6)
print(zero)

arrange = np.arange(1,11)
print(arrange)

# %%
arrange = np.linspace(0,2,5)
print(arrange)

# %%
mata = np.array([[12,6,7,5], [4,6,2,6]])
print(mat)

matb = np.array([[12,6,7,5], [4,6,2,6]])
print(matb)

print(mata + matb)

# %%
print(np.mean(arr))
print(np.max(arr))
print(np.min(arr))
print(np.std(arr))

# %%
# group A  [60, 70, 80]  mean 70 (low)

score1 = np.array([60, 70,80])
print(score1.mean())
print(score1.std())
# group B [30, 70, 110] mean 70 (high)

score2 =np.array([30, 70, 110])
print(score2.mean())
print(score2.std())

# %%
temps = np.array([30,31,29,32,28,35,37])

print(temps.mean())
print(temps.std())
